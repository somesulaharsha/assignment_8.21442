# %% [markdown]
# #  Create an sqlalchemy engine using a sample from the data set

# %%
import pandas as pd
sample = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data",header=None)
type(dataSet)
from sqlalchemy import create_engine
engine = create_engine('sqlite:///sample', echo=True)

# %%
conn = engine.connect()
# Out:
# 2019-01-28 04:14:58,693 INFO sqlalchemy.engine.base.Engine SELECT CAST('test plain returns' AS VARCHAR(60)) AS anon_1
# 2019-01-28 04:14:58,694 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-28 04:14:58,695 INFO sqlalchemy.engine.base.Engine SELECT CAST('test unicode returns' AS VARCHAR(60)) AS anon_1
# 2019-01-28 04:14:58,696 INFO sqlalchemy.engine.base.Engine ()

# %%
from sqlalchemy import Table, Column, Integer, String, MetaData, ForeignKey
metadata = MetaData()
employee = Table('employee', metadata,
              Column('id', Integer, primary_key=True),
              Column('age', Integer),
              Column('workclass', String),
              Column('fnlwgt', Integer),
              Column('education', String),
              Column('education_num', Integer),
              Column('marital_status', String),
              Column('occupation', String),
              Column('relationship', String),
              Column('rasexce', String),
              Column('sex', String),
              Column('capital_gain', Integer),
              Column('capital_loss', Integer),
              Column('hours_per_week', Integer),
              Column('native_country', String),
              Column('salary', String),)

# %%
#metadata.create_all(engine) // view the query

# %%
ns1 = employee.insert().values(id=1, age=39,workclass='State-gov', fnlwgt=77516
                               ,education='Bachelors', education_num=13,marital_status='Never-married', occupation='Adm-clerical'
                            ,relationship='Not-in-family', rasexce='white',sex='Male', capital_gain=2174
                              ,capital_loss=0, hours_per_week=40,native_country='united-states', salary='<=50k'
                              )
ins2 = employee.insert().values(id=2, age=50,workclass='Self-emp-not-inc', fnlwgt=83311
                               ,education='Bachelors', education_num=13,marital_status='Married-civ-spouse', occupation='Exec-managerial'
                              ,relationship='Husband', rasexce='white',sex='Male', capital_gain=0
                              ,capital_loss=0, hours_per_week=13,native_country='united-states', salary='<=50k'
                              )
ins3 = employee.insert().values(id=3, age=38,workclass='Private', fnlwgt=215646
                               ,education='HS-grad', education_num=9,marital_status='Divorced', occupation='Handlers-cleaners'
                              ,relationship='Not-in-family', rasexce='white',sex='Male', capital_gain=0
                              ,capital_loss=0, hours_per_week=40,native_country='united-states', salary='<=50k'
                              )
#str(ins1)
#ins1.compile().params  # to view the data to be inserted
conn.execute(ins1)
conn.execute(ins2)
conn.execute(ins3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-642fd97c0e3c> in <module>()
#      16 #str(ins1)
#      17 #ins1.compile().params  # to view the data to be inserted
# ---> 18 conn.execute(ins1)
#      19 conn.execute(ins2)
#      20 conn.execute(ins3)
#
# NameError: name 'ins1' is not defined

# %%
from sqlalchemy.sql import select
s = select([employee])
result = conn.execute(s)
row = result.fetchall()
print(row)

# %% [markdown]
# 2. Write two basic update queries¶

# %%
from sqlalchemy import update

stmt = update(employee).where(employee.c.id==1).values(age=49)
stmt1 = update(employee).where(employee.c.id==1).values(marital_status='Married')
conn.execute(stmt)
conn.execute(stmt1)

# %%
s = select([employee])
result = conn.execute(s)
row = result.fetchall()
print(row)
# Out:
# 2019-01-28 04:15:01,198 INFO sqlalchemy.engine.base.Engine SELECT employee.id, employee.age, employee.workclass, employee.fnlwgt, employee.education, employee.education_num, employee.marital_status, employee.occupation, employee.relationship, employee.rasexce, employee.sex, employee.capital_gain, employee.capital_loss, employee.hours_per_week, employee.native_country, employee.salary
# FROM employee
# 2019-01-28 04:15:01,200 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-28 04:15:01,201 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-15-1debbcec80fc> in <module>()
#       1 s = select([employee])
# ----> 2 result = conn.execute(s)
#       3 row = result.fetchall()
#       4 print(row)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: employee [SQL: 'SELECT employee.id, employee.age, employee.workclass, employee.fnlwgt, employee.education, employee.education_num, employee.marital_status, employee.occupation, employee.relationship, employee.rasexce, employee.sex, employee.capital_gain, employee.capital_loss, employee.hours_per_week, employee.native_country, employee.salary \nFROM employee'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
from sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()

# %%
stmt1=employee.delete().where(employee.c.id==1)
stmt2=employee.delete().where(employee.c.id==2 and employee.c.sex=='Male')
conn.execute(stmt1)
conn.execute(stmt2)
# Out:
# 2019-01-28 04:15:03,524 INFO sqlalchemy.engine.base.Engine DELETE FROM employee WHERE employee.id = ?
# 2019-01-28 04:15:03,526 INFO sqlalchemy.engine.base.Engine (1,)
# 2019-01-28 04:15:03,527 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-5630e86be3e1> in <module>()
#       1 stmt1=employee.delete().where(employee.c.id==1)
#       2 stmt2=employee.delete().where(employee.c.id==2 and employee.c.sex=='Male')
# ----> 3 conn.execute(stmt1)
#       4 conn.execute(stmt2)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: employee [SQL: 'DELETE FROM employee WHERE employee.id = ?'] [parameters: (1,)] (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
s = select([employee])
result = conn.execute(s)
row = result.fetchall()
print(row)
# Out:
# 2019-01-28 04:15:04,608 INFO sqlalchemy.engine.base.Engine SELECT employee.id, employee.age, employee.workclass, employee.fnlwgt, employee.education, employee.education_num, employee.marital_status, employee.occupation, employee.relationship, employee.rasexce, employee.sex, employee.capital_gain, employee.capital_loss, employee.hours_per_week, employee.native_country, employee.salary
# FROM employee
# 2019-01-28 04:15:04,609 INFO sqlalchemy.engine.base.Engine ()
# 2019-01-28 04:15:04,611 INFO sqlalchemy.engine.base.Engine ROLLBACK
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-18-1debbcec80fc> in <module>()
#       1 s = select([employee])
# ----> 2 result = conn.execute(s)
#       3 row = result.fetchall()
#       4 print(row)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: employee [SQL: 'SELECT employee.id, employee.age, employee.workclass, employee.fnlwgt, employee.education, employee.education_num, employee.marital_status, employee.occupation, employee.relationship, employee.rasexce, employee.sex, employee.capital_gain, employee.capital_loss, employee.hours_per_week, employee.native_country, employee.salary \nFROM employee'] (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# 4. Write two filter queries¶

# %%
rom sqlalchemy.orm import sessionmaker
Session = sessionmaker(bind=engine)
session = Session()
# Out:
#   File "<ipython-input-19-eefdfe04da81>", line 1
#     rom sqlalchemy.orm import sessionmaker
#                  ^
# SyntaxError: invalid syntax

# %%
stmt1= session.query(employee).filter(employee.c.id=='Male').first()
stmt2= session.query(employee).filter(employee.c.hours_per_week==45).first()
# Out:
# 2019-01-28 04:15:09,467 INFO sqlalchemy.engine.base.Engine BEGIN (implicit)
# 2019-01-28 04:15:09,471 INFO sqlalchemy.engine.base.Engine SELECT employee.id AS employee_id, employee.age AS employee_age, employee.workclass AS employee_workclass, employee.fnlwgt AS employee_fnlwgt, employee.education AS employee_education, employee.education_num AS employee_education_num, employee.marital_status AS employee_marital_status, employee.occupation AS employee_occupation, employee.relationship AS employee_relationship, employee.rasexce AS employee_rasexce, employee.sex AS employee_sex, employee.capital_gain AS employee_capital_gain, employee.capital_loss AS employee_capital_loss, employee.hours_per_week AS employee_hours_per_week, employee.native_country AS employee_native_country, employee.salary AS employee_salary
# FROM employee
# WHERE employee.id = ?
#  LIMIT ? OFFSET ?
# 2019-01-28 04:15:09,472 INFO sqlalchemy.engine.base.Engine ('Male', 1, 0)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-20-2d668c8db5e5> in <module>()
# ----> 1 stmt1= session.query(employee).filter(employee.c.id=='Male').first()
#       2 stmt2= session.query(employee).filter(employee.c.hours_per_week==45).first()
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in first(self)
#    3008             ret = list(self)[0:1]
#    3009         else:
# -> 3010             ret = list(self[0:1])
#    3011         if len(ret) > 0:
#    3012             return ret[0]
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in __getitem__(self, item)
#    2798                 return list(res)[None : None : item.step]
#    2799             else:
# -> 2800                 return list(res)
#    2801         else:
#    2802             if item == -1:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in __iter__(self)
#    3110         if self._autoflush and not self._populate_existing:
#    3111             self.session._autoflush()
# -> 3112         return self._execute_and_instances(context)
#    3113
#    3114     def __str__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in _execute_and_instances(self, querycontext)
#    3135         )
#    3136
# -> 3137         result = conn.execute(querycontext.statement, self._params)
#    3138         return loading.instances(querycontext.query, result, querycontext)
#    3139
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: employee [SQL: 'SELECT employee.id AS employee_id, employee.age AS employee_age, employee.workclass AS employee_workclass, employee.fnlwgt AS employee_fnlwgt, employee.education AS employee_education, employee.education_num AS employee_education_num, employee.marital_status AS employee_marital_status, employee.occupation AS employee_occupation, employee.relationship AS employee_relationship, employee.rasexce AS employee_rasexce, employee.sex AS employee_sex, employee.capital_gain AS employee_capital_gain, employee.capital_loss AS employee_capital_loss, employee.hours_per_week AS employee_hours_per_week, employee.native_country AS employee_native_country, employee.salary AS employee_salary \nFROM employee \nWHERE employee.id = ?\n LIMIT ? OFFSET ?'] [parameters: ('Male', 1, 0)] (Background on this error at: http://sqlalche.me/e/e3q8)

# %% [markdown]
# 5. Write two function queries

# %%
from sqlalchemy import func
stmt1 = session.query(func.count('*')).select_from(employee).scalar()
stmt2 = session.query(func.count(employee.c.id)).scalar()
print(stmt1)
print(stmt2)
# Out:
# 2019-01-28 04:15:16,445 INFO sqlalchemy.engine.base.Engine SELECT count(?) AS count_1
# FROM employee
# 2019-01-28 04:15:16,446 INFO sqlalchemy.engine.base.Engine ('*',)
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#
# OperationalError: no such table: employee
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-4ce002885b5d> in <module>()
#       1 from sqlalchemy import func
# ----> 2 stmt1 = session.query(func.count('*')).select_from(employee).scalar()
#       3 stmt2 = session.query(func.count(employee.c.id)).scalar()
#       4 print(stmt1)
#       5 print(stmt2)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in scalar(self)
#    3098         """
#    3099         try:
# -> 3100             ret = self.one()
#    3101             if not isinstance(ret, tuple):
#    3102                 return ret
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in one(self)
#    3068         """
#    3069         try:
# -> 3070             ret = self.one_or_none()
#    3071         except orm_exc.MultipleResultsFound:
#    3072             raise orm_exc.MultipleResultsFound(
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in one_or_none(self)
#    3037
#    3038         """
# -> 3039         ret = list(self)
#    3040
#    3041         l = len(ret)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in __iter__(self)
#    3110         if self._autoflush and not self._populate_existing:
#    3111             self.session._autoflush()
# -> 3112         return self._execute_and_instances(context)
#    3113
#    3114     def __str__(self):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/orm/query.py in _execute_and_instances(self, querycontext)
#    3135         )
#    3136
# -> 3137         result = conn.execute(querycontext.statement, self._params)
#    3138         return loading.instances(querycontext.query, result, querycontext)
#    3139
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object_, *multiparams, **params)
#     972             raise exc.ObjectNotExecutableError(object_)
#     973         else:
# --> 974             return meth(self, multiparams, params)
#     975
#     976     def _execute_function(self, func, multiparams, params):
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     271     def _execute_on_connection(self, connection, multiparams, params):
#     272         if self.supports_execution:
# --> 273             return connection._execute_clauseelement(self, multiparams, params)
#     274         else:
#     275             raise exc.ObjectNotExecutableError(self)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1091             distilled_params,
#    1092             compiled_sql,
# -> 1093             distilled_params,
#    1094         )
#    1095         if self._has_events or self.engine._has_events:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1232         except BaseException as e:
#    1233             self._handle_dbapi_exception(
# -> 1234                 e, statement, parameters, cursor, context
#    1235             )
#    1236
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1450                 util.raise_from_cause(newraise, exc_info)
#    1451             elif should_wrap:
# -> 1452                 util.raise_from_cause(sqlalchemy_exception, exc_info)
#    1453             else:
#    1454                 util.reraise(*exc_info)
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     294     exc_type, exc_value, exc_tb = exc_info
#     295     cause = exc_value if exc_value is not exception else None
# --> 296     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     297
#     298
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     274             value.__cause__ = cause
#     275         if value.__traceback__ is not tb:
# --> 276             raise value.with_traceback(tb)
#     277         raise value
#     278
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1228                 if not evt_handled:
#    1229                     self.dialect.do_execute(
# -> 1230                         cursor, statement, parameters, context
#    1231                     )
#    1232         except BaseException as e:
#
# ~/anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     534
#     535     def do_execute(self, cursor, statement, parameters, context=None):
# --> 536         cursor.execute(statement, parameters)
#     537
#     538     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: employee [SQL: 'SELECT count(?) AS count_1 \nFROM employee'] [parameters: ('*',)] (Background on this error at: http://sqlalche.me/e/e3q8)
